# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Coronary heart disease is abbreviated to CHD throughout the following notebook

# %%
pd.read_csv("SAheart.csv", index_col=0) #dataset of heart disease in Sth African males
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 1          160    12.00   5.73      23.11  Present     49    25.30    97.20
# 2          144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 3          118     0.08   3.48      32.28  Present     52    29.14     3.81
# 4          170     7.50   6.41      38.03  Present     51    31.99    24.26
# 5          134    13.60   3.50      27.78  Present     60    25.99    57.34
# ...        ...      ...    ...        ...      ...    ...      ...      ...
# 459        214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 460        182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 461        108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 462        118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 463        132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#            age  chd
# row.names
# ...

# %%
SAheart_df = pd.read_csv("SAheart.csv", index_col=0) #assign the dataset a new variable SAheart_df

# %%
SAheart_df#change famhist to numerical
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 1          160    12.00   5.73      23.11  Present     49    25.30    97.20
# 2          144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 3          118     0.08   3.48      32.28  Present     52    29.14     3.81
# 4          170     7.50   6.41      38.03  Present     51    31.99    24.26
# 5          134    13.60   3.50      27.78  Present     60    25.99    57.34
# ...        ...      ...    ...        ...      ...    ...      ...      ...
# 459        214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 460        182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 461        108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 462        118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 463        132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#            age  chd
# row.names
# ...

# %%
dataMapping = {"Present" : 1,
              "Absent" : 0}
dataMapping #converting categorical data to ordinal data
# Out:
# {'Present': 1, 'Absent': 0}

# %%
SAheart_df['fam_hist'] = SAheart_df['famhist'].map(dataMapping)

# %%
SAheart_df #introduced a new column fam_hist
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 1          160    12.00   5.73      23.11  Present     49    25.30    97.20
# 2          144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 3          118     0.08   3.48      32.28  Present     52    29.14     3.81
# 4          170     7.50   6.41      38.03  Present     51    31.99    24.26
# 5          134    13.60   3.50      27.78  Present     60    25.99    57.34
# ...        ...      ...    ...        ...      ...    ...      ...      ...
# 459        214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 460        182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 461        108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 462        118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 463        132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#            age  chd  fam_hist
# row.names
# ...

# %%
SAheart_df.info() #describe the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 1 to 463
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        462 non-null    int64
#  1   tobacco    462 non-null    float64
#  2   ldl        462 non-null    float64
#  3   adiposity  462 non-null    float64
#  4   famhist    462 non-null    object
#  5   typea      462 non-null    int64
#  6   obesity    462 non-null    float64
#  7   alcohol    462 non-null    float64
#  8   age        462 non-null    int64
#  9   chd        462 non-null    int64
#  10  fam_hist   462 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 43.3+ KB

# %%
SAheart_df.describe() #exploratory data on the dataframe SAheart_df
# Out:
#               sbp     tobacco         ldl   adiposity       typea     obesity  \
# count  462.000000  462.000000  462.000000  462.000000  462.000000  462.000000
# mean   138.326840    3.635649    4.740325   25.406732   53.103896   26.044113
# std     20.496317    4.593024    2.070909    7.780699    9.817534    4.213680
# min    101.000000    0.000000    0.980000    6.740000   13.000000   14.700000
# 25%    124.000000    0.052500    3.282500   19.775000   47.000000   22.985000
# 50%    134.000000    2.000000    4.340000   26.115000   53.000000   25.805000
# 75%    148.000000    5.500000    5.790000   31.227500   60.000000   28.497500
# max    218.000000   31.200000   15.330000   42.490000   78.000000   46.580000
#
#           alcohol         age         chd    fam_hist
# count  462.000000  462.000000  462.000000  462.000000
# mean    17.044394   42.816017    0.346320    0.415584
# std     24.481059   14.608956    0.476313    0.493357
# ...

# %%
SAheart_df.isnull().sum() #look for any missing data
# Out:
# sbp          0
# tobacco      0
# ldl          0
# adiposity    0
# famhist      0
# typea        0
# obesity      0
# alcohol      0
# age          0
# chd          0
# fam_hist     0
# dtype: int64

# %%
SAheart_df[(SAheart_df["age"] >=35) & (SAheart_df["chd"] ==0)] #men over 35 without chd
Table1_df = SAheart_df[(SAheart_df["age"] >=35) & (SAheart_df["chd"] ==0)]

# %%
Table1_df #men over 35 without chd
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 3          118     0.08   3.48      32.28  Present     52    29.14     3.81
# 6          132     6.20   6.47      36.21  Present     62    30.77    14.14
# 7          142     4.05   3.38      16.20   Absent     59    20.81     2.62
# 15         112     9.65   2.29      17.20  Present     54    23.53     0.68
# 16         117     1.53   2.44      28.95  Present     35    25.89    30.03
# ...        ...      ...    ...        ...      ...    ...      ...      ...
# 454        154     5.53   3.20      28.81  Present     61    26.15    42.79
# 458        170     0.40   4.11      42.06  Present     56    33.10     2.06
# 459        214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 461        108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 462        118     5.40  11.61      30.79   Absent     64    27.35    23.97
#
#            age  chd  fam_hist
# row.names
# ...

# %%
Table1_df.describe() #exploratory data for the men over 35 w/o chd
# Out:
#               sbp     tobacco         ldl   adiposity       typea     obesity  \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.000000
# mean   140.564972    4.006667    4.788418   27.814689   51.598870   26.696893
# std     19.876251    4.074013    1.992517    6.359908    9.362194    3.892319
# min    106.000000    0.000000    0.980000   12.300000   13.000000   18.360000
# 25%    128.000000    0.600000    3.480000   23.510000   47.000000   24.080000
# 50%    136.000000    3.200000    4.550000   28.830000   52.000000   26.160000
# 75%    152.000000    6.000000    5.860000   32.480000   58.000000   28.850000
# max    214.000000   20.000000   15.330000   42.060000   77.000000   40.340000
#
#           alcohol         age    chd    fam_hist
# count  177.000000  177.000000  177.0  177.000000
# mean    18.816893   49.610169    0.0    0.389831
# std     24.505560    8.292967    0.0    0.489095
# min      0.000000   35.000000    0.0    0.000000
# ...

# %%
SAheart_df[(SAheart_df["age"] >=35) & (SAheart_df["chd"] ==1)] #men over 35 with chd
Table2_df = SAheart_df[(SAheart_df["age"] >=35) & (SAheart_df["chd"] ==1)] #men over 35 with chd

# %%
Table2_df #men over 35 with chd
# Out:
#            sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 1          160    12.00  5.73      23.11  Present     49    25.30    97.20
# 2          144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 4          170     7.50  6.41      38.03  Present     51    31.99    24.26
# 5          134    13.60  3.50      27.78  Present     60    25.99    57.34
# 8          114     4.08  4.59      14.60  Present     62    23.11     6.72
# ...        ...      ...   ...        ...      ...    ...      ...      ...
# 451        144     4.00  5.03      25.78  Present     57    27.55    90.00
# 455        124     1.60  7.22      39.68  Present     36    31.50     0.00
# 456        146     0.64  4.82      28.02   Absent     60    28.11     8.23
# 460        182     4.20  4.41      32.10   Absent     52    28.61    18.72
# 463        132     0.00  4.82      33.41  Present     62    14.70     0.00
#
#            age  chd  fam_hist
# row.names
# ...

# %%
Table2_df.describe() #exploratory data for men over 35 with chd
# Out:
#               sbp     tobacco         ldl   adiposity       typea     obesity  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean   145.478873    5.913521    5.585915   29.110141   54.140845   26.914577
# std     23.559708    5.748637    2.181926    6.487404   10.385199    4.375174
# min    102.000000    0.000000    2.050000   13.680000   20.000000   14.700000
# 25%    130.000000    1.505000    3.987500   24.522500   47.000000   24.100000
# 50%    140.000000    4.240000    5.160000   29.265000   54.000000   26.650000
# 75%    160.000000    8.712500    6.665000   34.195000   61.000000   28.840000
# max    218.000000   31.200000   14.160000   42.490000   78.000000   45.720000
#
#           alcohol         age    chd    fam_hist
# count  142.000000  142.000000  142.0  142.000000
# mean    18.763592   52.978873    1.0    0.626761
# std     26.417251    7.790218    0.0    0.485377
# min      0.000000   36.000000    1.0    0.000000
# ...

# %%
SAheart_df[(SAheart_df["age"] <=35) & (SAheart_df["chd"] ==0)] #men under 35 without chd
Table3_df = SAheart_df[(SAheart_df["age"] <=35) & (SAheart_df["chd"] ==0)]

# %%
Table3_df #men under 35 without chd
# Out:
#            sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 9          114     0.00  3.83      19.40  Present     49    24.86     2.49
# 13         118     0.00  1.88      10.05   Absent     59    21.57     0.00
# 14         132     0.00  1.87      17.21   Absent     49    23.63     0.97
# 37         140     3.90  7.32      25.05   Absent     47    27.36    36.77
# 39         130     0.00  2.82      19.63  Present     70    24.86     0.00
# ...        ...      ...   ...        ...      ...    ...      ...      ...
# 447        136     2.80  2.53       9.28  Present     61    20.70     4.55
# 449        130     0.00  1.88      12.51  Present     52    20.28     0.00
# 450        124     1.80  3.74      16.64  Present     42    22.26    10.49
# 452        136     1.81  3.31       6.74   Absent     63    19.57    24.94
# 453        120     0.00  2.77      13.35   Absent     67    23.37     1.03
#
#            age  chd  fam_hist
# row.names
# ...

# %%
Table3_df.describe() #men under 35 without chd
# Out:
#               sbp     tobacco         ldl   adiposity       typea     obesity  \
# count  126.000000  126.000000  126.000000  126.000000  126.000000  126.000000
# mean   128.293651    0.726270    3.719048   18.567143   53.571429   24.406032
# std     11.574501    1.325342    1.470178    6.178917    9.714672    3.988503
# min    101.000000    0.000000    1.070000    6.740000   26.000000   17.750000
# 25%    120.000000    0.000000    2.702500   13.210000   47.000000   21.902500
# 50%    128.000000    0.035000    3.545000   18.245000   54.000000   23.700000
# 75%    136.000000    0.855000    4.330000   23.895000   60.750000   26.460000
# max    166.000000    7.200000    8.220000   31.790000   73.000000   46.580000
#
#           alcohol         age    chd    fam_hist
# count  126.000000  126.000000  126.0  126.000000
# mean    11.956667   23.714286    0.0    0.222222
# std     21.384662    6.463259    0.0    0.417399
# min      0.000000   15.000000    0.0    0.000000
# ...

# %%
SAheart_df[(SAheart_df["age"] <=35) & (SAheart_df["chd"] ==1)] #men under 35 with chd
Table4_df = SAheart_df[(SAheart_df["age"] <=35) & (SAheart_df["chd"] ==1)]

# %%
Table4_df
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 21         106     1.61   1.74      12.32   Absent     74    20.92    13.37
# 36         122     4.26   4.44      13.04   Absent     57    19.49    48.99
# 48         116     1.91   7.56      26.45  Present     52    30.01     3.60
# 54         134     8.08   1.55      17.50  Present     56    22.65    66.65
# 70         122     0.00   3.37      16.10   Absent     67    21.06     0.00
# 117        140     4.50   4.59      18.01   Absent     63    21.91    22.09
# 133        134     1.50   3.73      21.53   Absent     41    24.70    11.11
# 142        130     2.78   4.89       9.39  Present     63    19.30    17.47
# 149        136     1.50   6.06      26.54   Absent     54    29.38    14.50
# 186        122     4.40   3.18      11.59  Present     59    21.94     0.00
# 202        136     3.15   4.37      20.22  Present     59    25.12    47.16
# ...

# %%
Table4_df.info() #type of data and null sets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 21 to 457
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        18 non-null     int64
#  1   tobacco    18 non-null     float64
#  2   ldl        18 non-null     float64
#  3   adiposity  18 non-null     float64
#  4   famhist    18 non-null     object
#  5   typea      18 non-null     int64
#  6   obesity    18 non-null     float64
#  7   alcohol    18 non-null     float64
#  8   age        18 non-null     int64
#  9   chd        18 non-null     int64
#  10  fam_hist   18 non-null     int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 1.7+ KB

# %%
Table4_df.describe() #exploratory data of men under 35 with chd
# Out:
#              sbp    tobacco       ldl  adiposity      typea    obesity  \
# count   18.00000  18.000000  18.00000  18.000000  18.000000  18.000000
# mean   130.00000   2.458889   4.71500  20.311111  57.277778  24.322222
# std     20.36144   2.087830   2.47114   6.640417   8.843779   3.908598
# min    106.00000   0.000000   1.55000   9.390000  41.000000  18.460000
# 25%    119.00000   1.185000   3.22750  13.805000  49.750000  21.272500
# 50%    129.00000   2.075000   4.37000  20.875000  57.500000  24.015000
# 75%    136.00000   3.982500   5.76750  26.400000  63.000000  28.122500
# max    198.00000   8.080000  11.89000  29.070000  74.000000  30.220000
#
#          alcohol        age   chd   fam_hist
# count  18.000000  18.000000  18.0  18.000000
# mean   22.156111  29.111111   1.0   0.388889
# std    24.737296   4.689022   0.0   0.501631
# min     0.000000  17.000000   1.0   0.000000
# 25%     3.097500  27.250000   1.0   0.000000
# 50%    13.935000  31.000000   1.0   0.000000
# ...

# %%
SAheart_df.describe().loc[['mean'], :]
mean1_df = SAheart_df.describe().loc[['mean'], :] #mean data for entire dataset

# %%
mean1_df
# Out:
#             sbp   tobacco       ldl  adiposity      typea    obesity  \
# mean  138.32684  3.635649  4.740325  25.406732  53.103896  26.044113
#
#         alcohol        age      chd  fam_hist
# mean  17.044394  42.816017  0.34632  0.415584

# %%
mean2_df = Table1_df.describe().loc[['mean'], :] #mean data for over 35 w/o chd

# %%
mean2_df
# Out:
#              sbp   tobacco       ldl  adiposity     typea    obesity  \
# mean  140.564972  4.006667  4.788418  27.814689  51.59887  26.696893
#
#         alcohol        age  chd  fam_hist
# mean  18.816893  49.610169  0.0  0.389831

# %%
mean3_df = Table2_df.describe().loc[['mean'], :] #mean data for over 35 with chd

# %%
mean3_df
# Out:
#              sbp   tobacco       ldl  adiposity      typea    obesity  \
# mean  145.478873  5.913521  5.585915  29.110141  54.140845  26.914577
#
#         alcohol        age  chd  fam_hist
# mean  18.763592  52.978873  1.0  0.626761

# %%
mean4_df = Table3_df.describe().loc[['mean'], :] #mean data for under 35 without chd

# %%
mean4_df
# Out:
#              sbp  tobacco       ldl  adiposity      typea    obesity  \
# mean  128.293651  0.72627  3.719048  18.567143  53.571429  24.406032
#
#         alcohol        age  chd  fam_hist
# mean  11.956667  23.714286  0.0  0.222222

# %%
mean5_df = Table4_df.describe().loc[['mean'], :]              #men under 35 with chd

# %%
mean5_df
# Out:
#         sbp   tobacco    ldl  adiposity      typea    obesity    alcohol  \
# mean  130.0  2.458889  4.715  20.311111  57.277778  24.322222  22.156111
#
#             age  chd  fam_hist
# mean  29.111111  1.0  0.388889

# %%
pd.concat([mean1_df,mean2_df,mean3_df,mean4_df,mean5_df]) #only looking at averages of the data in a table/dataframe
# Out:
#              sbp   tobacco       ldl  adiposity      typea    obesity  \
# mean  138.326840  3.635649  4.740325  25.406732  53.103896  26.044113
# mean  140.564972  4.006667  4.788418  27.814689  51.598870  26.696893
# mean  145.478873  5.913521  5.585915  29.110141  54.140845  26.914577
# mean  128.293651  0.726270  3.719048  18.567143  53.571429  24.406032
# mean  130.000000  2.458889  4.715000  20.311111  57.277778  24.322222
#
#         alcohol        age      chd  fam_hist
# mean  17.044394  42.816017  0.34632  0.415584
# mean  18.816893  49.610169  0.00000  0.389831
# mean  18.763592  52.978873  1.00000  0.626761
# mean  11.956667  23.714286  0.00000  0.222222
# mean  22.156111  29.111111  1.00000  0.388889

# %%
Table6_df = pd.concat([mean1_df,mean2_df,mean3_df,mean4_df,mean5_df])

# %%
Table6_df
# Out:
#              sbp   tobacco       ldl  adiposity      typea    obesity  \
# mean  138.326840  3.635649  4.740325  25.406732  53.103896  26.044113
# mean  140.564972  4.006667  4.788418  27.814689  51.598870  26.696893
# mean  145.478873  5.913521  5.585915  29.110141  54.140845  26.914577
# mean  128.293651  0.726270  3.719048  18.567143  53.571429  24.406032
# mean  130.000000  2.458889  4.715000  20.311111  57.277778  24.322222
#
#         alcohol        age      chd  fam_hist
# mean  17.044394  42.816017  0.34632  0.415584
# mean  18.816893  49.610169  0.00000  0.389831
# mean  18.763592  52.978873  1.00000  0.626761
# mean  11.956667  23.714286  0.00000  0.222222
# mean  22.156111  29.111111  1.00000  0.388889

# %%
Table6_df['Sample'] = ['All_subjects', 'Over35_withoutCHD', 'Over35_withCHD','Under35_withoutCHD','Under35_withCHD']
#added new column

# %%
Table6_df['Sample']
# Out:
# mean          All_subjects
# mean     Over35_withoutCHD
# mean        Over35_withCHD
# mean    Under35_withoutCHD
# mean       Under35_withCHD
# Name: Sample, dtype: object

# %%
Table6_df #new column added
# Out:
#              sbp   tobacco       ldl  adiposity      typea    obesity  \
# mean  138.326840  3.635649  4.740325  25.406732  53.103896  26.044113
# mean  140.564972  4.006667  4.788418  27.814689  51.598870  26.696893
# mean  145.478873  5.913521  5.585915  29.110141  54.140845  26.914577
# mean  128.293651  0.726270  3.719048  18.567143  53.571429  24.406032
# mean  130.000000  2.458889  4.715000  20.311111  57.277778  24.322222
#
#         alcohol        age      chd  fam_hist              Sample
# mean  17.044394  42.816017  0.34632  0.415584        All_subjects
# mean  18.816893  49.610169  0.00000  0.389831   Over35_withoutCHD
# mean  18.763592  52.978873  1.00000  0.626761      Over35_withCHD
# mean  11.956667  23.714286  0.00000  0.222222  Under35_withoutCHD
# mean  22.156111  29.111111  1.00000  0.388889     Under35_withCHD

# %%
Table7_df = Table6_df[['Sample', 'age', 'chd','fam_hist','sbp','ldl','adiposity', 'obesity', 'alcohol', 'tobacco', 'typea']]

# %%
Table7_df #rerranging the columns in more suitable sequence
# Out:
#                   Sample        age      chd  fam_hist         sbp       ldl  \
# mean        All_subjects  42.816017  0.34632  0.415584  138.326840  4.740325
# mean   Over35_withoutCHD  49.610169  0.00000  0.389831  140.564972  4.788418
# mean      Over35_withCHD  52.978873  1.00000  0.626761  145.478873  5.585915
# mean  Under35_withoutCHD  23.714286  0.00000  0.222222  128.293651  3.719048
# mean     Under35_withCHD  29.111111  1.00000  0.388889  130.000000  4.715000
#
#       adiposity    obesity    alcohol   tobacco      typea
# mean  25.406732  26.044113  17.044394  3.635649  53.103896
# mean  27.814689  26.696893  18.816893  4.006667  51.598870
# mean  29.110141  26.914577  18.763592  5.913521  54.140845
# mean  18.567143  24.406032  11.956667  0.726270  53.571429
# mean  20.311111  24.322222  22.156111  2.458889  57.277778

# %%
Table8_df = Table7_df[['Sample','fam_hist', 'age', 'chd', 'ldl','alcohol', 'tobacco']]

# %%
Table8_df
# Out:
#                   Sample  fam_hist        age      chd       ldl    alcohol  \
# mean        All_subjects  0.415584  42.816017  0.34632  4.740325  17.044394
# mean   Over35_withoutCHD  0.389831  49.610169  0.00000  4.788418  18.816893
# mean      Over35_withCHD  0.626761  52.978873  1.00000  5.585915  18.763592
# mean  Under35_withoutCHD  0.222222  23.714286  0.00000  3.719048  11.956667
# mean     Under35_withCHD  0.388889  29.111111  1.00000  4.715000  22.156111
#
#        tobacco
# mean  3.635649
# mean  4.006667
# mean  5.913521
# mean  0.726270
# mean  2.458889

# %%
under35_dict = {'Sample': ['Under35_withoutCHD','Under35_withCHD'],
                'Observations': [126, 18],
               'Ave_age': [24, 29],
               'Family_hist': ['22per_cent','39per_cent'],
               'Blood_PRESSURE':[128.3, 130],
               'ldl_cholesterol': [3.72, 4.72],
               'alcohol': [11.9, 22.2],
               'tobacco': [0.73, 2.6]} #dictionary with relevant columns

# %%
under35_dict #dictionary of lists
# Out:
# {'Sample': ['Under35_withoutCHD', 'Under35_withCHD'],
#  'Observations': [126, 18],
#  'Ave_age': [24, 29],
#  'Family_hist': ['22per_cent', '39per_cent'],
#  'Blood_PRESSURE': [128.3, 130],
#  'ldl_cholesterol': [3.72, 4.72],
#  'alcohol': [11.9, 22.2],
#  'tobacco': [0.73, 2.6]}

# %%
Table_9 = pd.DataFrame(under35_dict) #covert the dictionary to a dataframe

# %%
Table_9 #dataframe of relevant under 35 year olds
# Out:
#                Sample  Observations  Ave_age Family_hist  Blood_PRESSURE  \
# 0  Under35_withoutCHD           126       24  22per_cent           128.3
# 1     Under35_withCHD            18       29  39per_cent           130.0
#
#    ldl_cholesterol  alcohol  tobacco
# 0             3.72     11.9     0.73
# 1             4.72     22.2     2.60

# %%
pd.concat([Table3_df, Table4_df])
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 9          114     0.00   3.83      19.40  Present     49    24.86     2.49
# 13         118     0.00   1.88      10.05   Absent     59    21.57     0.00
# 14         132     0.00   1.87      17.21   Absent     49    23.63     0.97
# 37         140     3.90   7.32      25.05   Absent     47    27.36    36.77
# 39         130     0.00   2.82      19.63  Present     70    24.86     0.00
# ...        ...      ...    ...        ...      ...    ...      ...      ...
# 282        106     1.08   4.37      26.08   Absent     67    24.07    17.74
# 303        138     2.27   6.41      29.07   Absent     58    30.22     2.93
# 347        198     0.52  11.89      27.68  Present     48    28.40    78.99
# 448        142     0.00   4.32      25.22   Absent     47    28.92     6.53
# 457        128     2.24   2.83      26.48   Absent     48    23.96    47.42
#
#            age  chd  fam_hist
# row.names
# ...

# %%
Table10_df = pd.concat([Table3_df, Table4_df]) #concatonate all under 35 data

# %%
Table10_df #all data for under 35 year old males as a single table
# Out:
#            sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 9          114     0.00   3.83      19.40  Present     49    24.86     2.49
# 13         118     0.00   1.88      10.05   Absent     59    21.57     0.00
# 14         132     0.00   1.87      17.21   Absent     49    23.63     0.97
# 37         140     3.90   7.32      25.05   Absent     47    27.36    36.77
# 39         130     0.00   2.82      19.63  Present     70    24.86     0.00
# ...        ...      ...    ...        ...      ...    ...      ...      ...
# 282        106     1.08   4.37      26.08   Absent     67    24.07    17.74
# 303        138     2.27   6.41      29.07   Absent     58    30.22     2.93
# 347        198     0.52  11.89      27.68  Present     48    28.40    78.99
# 448        142     0.00   4.32      25.22   Absent     47    28.92     6.53
# 457        128     2.24   2.83      26.48   Absent     48    23.96    47.42
#
#            age  chd  fam_hist
# row.names
# ...

# %%
year = [1990, 2000, 2010]
population_millions = [285, 350 , 430] #global population living with heart and circulatory disease. 
#Source British medical foundation August 2022. Reference in word document

# %%
plt.scatter(year, population_millions)
plt.show() #scatter graph showing the increase of heart disease between years 1990 and 2010.

# %%
diseaseGlobal_list = ['CHD' 'Stroke', 'COPD', 'Respiratory_infections', 'Lung_cancer'] 
diseaseQuantity_list = [9000000, 6600000, 3300000,2500000,2000000] 
#biggest killers global durden of disease for the year 2019

# %%
sns.pairplot(Table10_df)

# %%
plt.scatter(Table10_df["age"], Table10_df["alcohol"]) #alcohol consumption and age in all under 35 males

# %%
plt.scatter(Table10_df["age"], Table10_df["tobacco"]) #smoking intake and age in all under 35 males

# %%
plt.scatter(Table10_df["age"], Table10_df["tobacco"])

# %%
Table_9 # Summary of under 35 year old males key variables
# Out:
#                Sample  Observations  Ave_age Family_hist  Blood_PRESSURE  \
# 0  Under35_withoutCHD           126       24  22per_cent           128.3
# 1     Under35_withCHD            18       29  39per_cent           130.0
#
#    ldl_cholesterol  alcohol  tobacco
# 0             3.72     11.9     0.73
# 1             4.72     22.2     2.60

# %%
finaltable_dict = {'Sample': ['Under35yrs', 'Over35yrs'],
                  'CHD_present':['12.5per_cent','44.5per_cent'],
                  'CHD_absent': ['87.5per_cent','55.5per_cent']} #dictionary with final chd percentages of the total group

# %%
finaltable_dict
# Out:
# {'Sample': ['Under35yrs', 'Over35yrs'],
#  'CHD_present': ['12.5per_cent', '44.5per_cent'],
#  'CHD_absent': ['87.5per_cent', '55.5per_cent']}

# %%
Final_table = pd.DataFrame(finaltable_dict) #dataframe of the dictionary

# %%
Final_table #this table distills all the data into a single dataframe. Clearly CHD in the under 35's there is a
#12.5% occurance of chd, this increases to 44.5% in the over 35's.
# Out:
#        Sample   CHD_present    CHD_absent
# 0  Under35yrs  12.5per_cent  87.5per_cent
# 1   Over35yrs  44.5per_cent  55.5per_cent

# %%
finaltally_dict = {'Sample': ['Under35yrs', 'Over35yrs'],
                  'CHD_present':[18,142],
                  'CHD_absent': [126,177]} #dictionary with final chd tallies percentages of the total groupCHD

# %%
finaltally_dict
# Out:
# {'Sample': ['Under35yrs', 'Over35yrs'],
#  'CHD_present': [18, 142],
#  'CHD_absent': [126, 177]}

# %%
Final_tally = pd.DataFrame(finaltally_dict)

# %%
Final_tally
# Out:
#        Sample  CHD_present  CHD_absent
# 0  Under35yrs           18         126
# 1   Over35yrs          142         177

# %%
CHD_Under35 =['CHD_Present', 'CHD_Absent']
Total = [14,144]

# %%
plt.bar(CHD_Under35,Total) #under 35 year old males presence and absence of chd
plt.show()

# %%
CHD_Over35 =['CHD_Present', 'CHD_Absent']
Total = [142,177]

# %%
plt.bar(CHD_Over35,Total) #over 35 year old males presence and absence of chd 
plt.show()

# %%
Under_35noCHD = plt.scatter(Table3_df["alcohol"], Table3_df["tobacco"]) #males under 35 w/o chd x-axis alcohol, y axis tobacco

# %%
plt.scatter(Table3_df["alcohol"], Table3_df["tobacco"])

# %%
Table3_df.plot.scatter("alcohol","tobacco") #under 35 year olds without chd
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='tobacco'>

# %%
Under_35CHD = plt.scatter(Table4_df["alcohol"], Table4_df["tobacco"]) #males under 35 with chd alcohol v smoking

# %%
plt.scatter(Table4_df["alcohol"], Table4_df["tobacco"])

# %%
Table4_df.plot.scatter("alcohol","tobacco")#males under 35 with chd alcohol v smoking
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='tobacco'>
